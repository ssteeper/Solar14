# %%
# %pylab inline
from scipy import integrate
lat = 35
maxsd = 23.5  #max solar declination
degtorad = pi/180
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
m = .5; C = 0;
Ax = 1.0; Ay = .5; Bx = .94; By = .44;
xE1 = .25; yE1 = .032; xE2 = 1.60; yE2= 1.28;
focusx = 0.0; focusy = 0.5;

x = arange(xE1,xE2,.01)
y = m*x**2 + C

m1=.1
y1 = y[75:] - m1*(x[75:]-Ax)

m2=-.1
y2 = y[:75] - m2*(x[:75]-Ax)

#plotting
fig = plt.figure(figsize=(16, 10), dpi=100)
plot(x,y,color='black')  #perfect parabola
plot(x[75:],y1,color='red')  #top half flattened
plot(x[:75],y2,color='green')  #bottom half flattened

plot(array(Ax),array(Ay), '+', c='red', ms=10,lw = 5)
plot(array(focusx),array(focusy), 'd', c='red')  #focus

xlim(-.25, 2.0)
ylim(-.25, 1.5)
show()
